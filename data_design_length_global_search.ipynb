# %%
"""
r: Zongyi Li and Daniel Zhengyu Huang
"""

import numpy as np
import torch.nn.functional as F
import matplotlib.pyplot as plt
from timeit import default_timer
from catheter import *
from utilities3 import *
from Adam import Adam

torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
torch.backends.cudnn.deterministic = True
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("device is ", (device))
# Out:
# device is  cuda

# %%
def Lx2length(L_x, L_p, x1, x2, x3, h):
    l0, l1, l2, l3 = -x3, torch.sqrt((x2-x3)**2 + h**2), torch.sqrt((x1-x2)**2 + h**2), L_p+x1
    if L_x < -x3:
        l = L_x
    elif L_x < -x2:
        l = l0 + l1*(L_x + x3)/(x3-x2)
    elif L_x < -x1:
        l = l0 + l1 + l2*(L_x + x2)/(x2-x1)
    else:
        l = l0 + l1 + l2 + L_x+x1

    return l

def d2xy(d, L_p, x1, x2, x3, h):
    
    p0, p1, p2, p3 = torch.tensor([0.0,0.0]), torch.tensor([x3,0.0]), torch.tensor([x2, h]), torch.tensor([x1,0.0])
    v0, v1, v2, v3 = torch.tensor([x3-0,0.0]), torch.tensor([x2-x3,h]), torch.tensor([x1-x2,-h]), torch.tensor([-L_p-x1,0.0])
    l0, l1, l2, l3 = -x3, torch.sqrt((x2-x3)**2 + h**2), torch.sqrt((x1-x2)**2 + h**2), L_p+x1
    
    xx, yy = torch.zeros(d.shape), torch.zeros(d.shape)
    ind = (d < l0)
    xx[ind] = d[ind]*v0[0]/l0 + p0[0]
    yy[ind] = d[ind]*v0[1]/l0 + p0[1]
    
    ind = torch.logical_and(d < l0 + l1, d>=l0)
    xx[ind] = (d[ind]-l0)*v1[0]/l1 + p1[0] 
    yy[ind] = (d[ind]-l0)*v1[1]/l1 + p1[1]
    
    ind = torch.logical_and(d < l0 + l1 + l2, d>=l0 + l1)
    xx[ind] = (d[ind]-l0-l1)*v2[0]/l2 + p2[0]
    yy[ind] = (d[ind]-l0-l1)*v2[1]/l2 + p2[1]
    
    ind = (d>=l0 + l1 + l2)
    xx[ind] = (d[ind]-l0-l1-l2)*v3[0]/l3 + p3[0]
    yy[ind] = (d[ind]-l0-l1-l2)*v3[1]/l3 + p3[1]
    

    return xx, yy

def catheter_mesh_1d_total_length(L_x, L_p, x2, x3, h, N_s):
    x1 = -0.5*L_p
    # ncy = 20
    
    n_periods = torch.floor(L_x / L_p)
    L_x_last_period = L_x - n_periods*L_p
    L_p_s = ((x1 + L_p) + (0 - x3) + torch.sqrt((x2 - x1)**2 + h**2) + torch.sqrt((x3 - x2)**2 + h**2))
    L_s = L_p_s*n_periods + Lx2length(L_x_last_period, L_p, x1, x2, x3, h)
    
    # from 0
    d_arr = torch.linspace(0, 1, N_s) * L_s
    
    # TODO do not compute gradient for floor
    period_arr = torch.floor(d_arr / L_p_s).detach()
    d_arr -= period_arr * L_p_s

    
    xx, yy = d2xy(d_arr, L_p, x1, x2, x3, h)
        
    xx = xx - period_arr*L_p
    
    
    X_Y = torch.zeros((1, N_s, 2), dtype=torch.float).to(device)
    X_Y[0, :, 0], X_Y[0, :, 1] = xx, yy
    return X_Y, xx, yy

# %%
################################################################
# inverse optimization for 1d
################################################################


model = torch.load("catheter_plain_length_model_1d1000", map_location=device)
print(count_params(model))

learning_rate = 0.001
epochs = 5001
step_size = 1000
gamma = 0.1
L_x = 500
N_s = 2001
xx_mask = (torch.linspace(1.0, 0, N_s) * (-L_x)).to(device)
# learning_rate = 0.001
# epochs = 5001
# step_size = 500
# gamma = 0.5

# constraints   
#               60 < L_p < 250
#               x1 = -0.5L_p 
#               -L_p/4 < x2 - x3 < L_p/4
#               15 < x3 - x1 < L_p/4
#               20 < h < 30

loss_min = np.inf
L_p_min, x2_min, x3_min = np.NaN, np.NaN, np.NaN
mesh_min = np.NaN
density_min = np.NaN
nLp = 190
for L_p in np.linspace(61, 249, nLp):
    print("L_p = ", L_p)
    x1 = -L_p/2
    for dx3_x1 in np.linspace(15, L_p/2, np.int64(np.round(2*(L_p/2 - 15)))+1):
        x3 = x1 + dx3_x1
        for x2 in np.linspace(-L_p, 0, np.int64(np.round(2*L_p))+1):
            for h in np.linspace(20, 30, 21):
                
                L_p, x2, x3, h =  torch.tensor(L_p, dtype=torch.float), torch.tensor(x2, dtype=torch.float), torch.tensor(x3, dtype=torch.float), torch.tensor(h, dtype=torch.float)

                x, XC, YC = catheter_mesh_1d_total_length(L_x, L_p, x2, x3, h, N_s)

                out = model(x).squeeze()
                loss = -torch.sum(torch.matmul(out, xx_mask))* L_x/N_s
                if loss < loss_min:
                    L_p_min, x2_min, x3_min, h_min = L_p, x2, x3, h
                    mesh_min = np.copy(x.detach().cpu().numpy())
                    density_min = np.copy(out.detach().cpu().numpy())
                    loss_min = loss
                    print(L_p_min, x2_min, x3_min, h_min, loss_min)
                
plt.figure(figsize=(5,4))
plt.title("Bacterial population")
plt.plot(xx_mask.detach().cpu().numpy(), density_min, "-o", fillstyle='none', markevery=len(xx_mask)//10, label="Prediction")
plt.plot(mesh_min[0, :, 0], mesh_min[0, :, 1], color="r", label="Design")

plt.legend()
plt.show()
# Out:
# 1336001
# L_p =  61.0
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(20.) tensor(1383478., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(20.5000) tensor(1361050., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(21.) tensor(1337339.2500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(21.5000) tensor(1312431.2500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(22.) tensor(1285901.6250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(22.5000) tensor(1258725., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(23.) tensor(1230547.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(23.5000) tensor(1201949.5000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(24.) tensor(1173107.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(24.5000) tensor(1143951.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(25.) tensor(1114310.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(25.5000) tensor(1084814.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(26.) tensor(1055433.5000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(26.5000) tensor(1027019.9375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(27.) tensor(999993.5000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(27.5000) tensor(974663.9375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(28.) tensor(950922.8125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(28.5000) tensor(927785.7500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(29.) tensor(904586.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(29.5000) tensor(882175.6875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-61.) tensor(-15.5000) tensor(30.) tensor(861670.4375, device='cuda:0', grad_fn=<DivBackward0>)
# /home/dzhuang/miniconda3/envs/qg/lib/python3.7/site-packages/ipykernel_launcher.py:41: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# tensor(61.) tensor(-60.5000) tensor(-15.5000) tensor(30.) tensor(854852.6250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-60.) tensor(-15.5000) tensor(30.) tensor(848431.2500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-59.5000) tensor(-15.5000) tensor(30.) tensor(842640.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-59.) tensor(-15.5000) tensor(30.) tensor(837376.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-58.5000) tensor(-15.5000) tensor(30.) tensor(832487.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-58.) tensor(-15.5000) tensor(30.) tensor(827586.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-57.5000) tensor(-15.5000) tensor(30.) tensor(822440.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-57.) tensor(-15.5000) tensor(30.) tensor(817428.1875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-56.5000) tensor(-15.5000) tensor(30.) tensor(812637.5000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-56.) tensor(-15.5000) tensor(30.) tensor(808462.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-55.5000) tensor(-15.5000) tensor(30.) tensor(804675.0625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-55.) tensor(-15.5000) tensor(30.) tensor(801166.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-54.5000) tensor(-15.5000) tensor(30.) tensor(797580.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-54.) tensor(-15.5000) tensor(30.) tensor(794118.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-53.5000) tensor(-15.5000) tensor(30.) tensor(790755.7500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-53.) tensor(-15.5000) tensor(30.) tensor(787670.5000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-52.5000) tensor(-15.5000) tensor(30.) tensor(784776.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-52.) tensor(-15.5000) tensor(30.) tensor(781934.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-51.5000) tensor(-15.5000) tensor(30.) tensor(779080.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-51.) tensor(-15.5000) tensor(30.) tensor(776253.1875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-50.5000) tensor(-15.5000) tensor(30.) tensor(773665.5625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-50.) tensor(-15.5000) tensor(30.) tensor(771032.6875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-49.5000) tensor(-15.5000) tensor(30.) tensor(768187.9375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-49.) tensor(-15.5000) tensor(30.) tensor(764844.2500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-48.5000) tensor(-15.5000) tensor(30.) tensor(760847.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-48.) tensor(-15.5000) tensor(30.) tensor(756336.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-47.5000) tensor(-15.5000) tensor(30.) tensor(751163.5625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-47.) tensor(-15.5000) tensor(30.) tensor(745260.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-46.5000) tensor(-15.5000) tensor(30.) tensor(739147.5625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-46.) tensor(-15.5000) tensor(30.) tensor(733010.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-45.5000) tensor(-15.5000) tensor(30.) tensor(726666.0625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-45.) tensor(-15.5000) tensor(30.) tensor(719856.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-44.5000) tensor(-15.5000) tensor(30.) tensor(713005.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-44.) tensor(-15.5000) tensor(30.) tensor(705792.6250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-43.5000) tensor(-15.5000) tensor(30.) tensor(698194.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-43.) tensor(-15.5000) tensor(30.) tensor(690821.7500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-42.5000) tensor(-15.5000) tensor(30.) tensor(683629.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-42.) tensor(-15.5000) tensor(30.) tensor(676773.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-41.5000) tensor(-15.5000) tensor(30.) tensor(670466.5000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-41.) tensor(-15.5000) tensor(30.) tensor(663781.8125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-40.5000) tensor(-15.5000) tensor(30.) tensor(656292.0625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-40.) tensor(-15.5000) tensor(30.) tensor(647129., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-39.5000) tensor(-15.5000) tensor(30.) tensor(636507.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-39.) tensor(-15.5000) tensor(30.) tensor(624687.5000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-38.5000) tensor(-15.5000) tensor(30.) tensor(612009.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-38.) tensor(-15.5000) tensor(30.) tensor(598712.2500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-37.5000) tensor(-15.5000) tensor(30.) tensor(584936.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-37.) tensor(-15.5000) tensor(30.) tensor(570753.2500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-36.5000) tensor(-15.5000) tensor(30.) tensor(555700.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-36.) tensor(-15.5000) tensor(30.) tensor(540082.6875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-35.5000) tensor(-15.5000) tensor(30.) tensor(524526.1875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-35.) tensor(-15.5000) tensor(30.) tensor(509361.3125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-34.5000) tensor(-15.5000) tensor(30.) tensor(494556.2812, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-34.) tensor(-15.5000) tensor(30.) tensor(480228.5312, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-33.5000) tensor(-15.5000) tensor(30.) tensor(466018.9375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-33.) tensor(-15.5000) tensor(30.) tensor(451960.3438, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-32.5000) tensor(-15.5000) tensor(30.) tensor(437797.4062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-32.) tensor(-15.5000) tensor(29.5000) tensor(437779.1250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-32.) tensor(-15.5000) tensor(30.) tensor(423672.4062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-31.5000) tensor(-15.5000) tensor(30.) tensor(409922.8438, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-31.) tensor(-15.5000) tensor(30.) tensor(396998.6562, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-30.5000) tensor(-15.5000) tensor(30.) tensor(384893.5938, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-30.) tensor(-15.5000) tensor(30.) tensor(373306.1562, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-29.5000) tensor(-15.5000) tensor(30.) tensor(362223., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-29.) tensor(-15.5000) tensor(30.) tensor(351762.5625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-28.5000) tensor(-15.5000) tensor(30.) tensor(342070.7812, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-28.) tensor(-15.5000) tensor(30.) tensor(333175.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-27.5000) tensor(-15.5000) tensor(30.) tensor(324895.4688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-27.) tensor(-15.5000) tensor(30.) tensor(316724.4688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-26.5000) tensor(-15.5000) tensor(30.) tensor(308926.9062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-26.) tensor(-15.5000) tensor(30.) tensor(301546.3438, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-25.5000) tensor(-15.5000) tensor(30.) tensor(294763.7812, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-25.) tensor(-15.5000) tensor(30.) tensor(288193.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-24.5000) tensor(-15.5000) tensor(30.) tensor(281932.1875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-24.) tensor(-15.5000) tensor(30.) tensor(276010.7500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-23.5000) tensor(-15.5000) tensor(30.) tensor(270303.7500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-23.) tensor(-15.5000) tensor(30.) tensor(264771.6250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-22.5000) tensor(-15.5000) tensor(30.) tensor(259487.4688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-22.) tensor(-15.5000) tensor(30.) tensor(254364.8594, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-21.5000) tensor(-15.5000) tensor(30.) tensor(249470.8438, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-21.) tensor(-15.5000) tensor(30.) tensor(244685.4375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-20.5000) tensor(-15.5000) tensor(30.) tensor(239914.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-20.) tensor(-15.5000) tensor(30.) tensor(235164.8750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-19.5000) tensor(-15.5000) tensor(30.) tensor(230316., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-19.) tensor(-15.5000) tensor(30.) tensor(225573.2969, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-18.5000) tensor(-15.5000) tensor(30.) tensor(221333.9531, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-18.) tensor(-15.5000) tensor(30.) tensor(217606.1406, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-17.5000) tensor(-15.5000) tensor(30.) tensor(214376.0938, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-17.) tensor(-15.5000) tensor(30.) tensor(211640.2812, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-16.5000) tensor(-15.5000) tensor(30.) tensor(209320.9219, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-16.) tensor(-15.5000) tensor(30.) tensor(207518.3438, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-15.5000) tensor(-15.5000) tensor(30.) tensor(206248.5781, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-15.) tensor(-15.5000) tensor(30.) tensor(205335.9531, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-14.5000) tensor(-15.5000) tensor(30.) tensor(204855.0625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-14.) tensor(-15.5000) tensor(30.) tensor(204585.6562, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(61.) tensor(-13.5000) tensor(-15.5000) tensor(30.) tensor(204552.2969, device='cuda:0', grad_fn=<DivBackward0>)
# L_p =  61.99470899470899
# L_p =  62.98941798941799
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8843/3419254090.py in <module>
#      41                 L_p, x2, x3, h =  torch.tensor(L_p, dtype=torch.float), torch.tensor(x2, dtype=torch.float), torch.tensor(x3, dtype=torch.float), torch.tensor(h, dtype=torch.float)
#      42
# ---> 43                 x, XC, YC = catheter_mesh_1d_total_length(L_x, L_p, x2, x3, h, N_s)
#      44
#      45                 out = model(x).squeeze()
#
# /central/home/dzhuang/Geo-FNO-catheter/catheter.py in catheter_mesh_1d_total_length(L_x, L_p, x2, x3, h, N_s)
#     462
#     463
# --> 464     xx, yy = d2xy(d_arr, L_p, x1, x2, x3, h)
#     465
#     466     xx = xx - period_arr*L_p
#
# /central/home/dzhuang/Geo-FNO-catheter/catheter.py in d2xy(d, L_p, x1, x2, x3, h)
#     432     ind = torch.logical_and(d < l0 + l1, d>=l0)
#     433     xx[ind] = (d[ind]-l0)*v1[0]/l1 + p1[0]
# --> 434     yy[ind] = (d[ind]-l0)*v1[1]/l1 + p1[1]
#     435
#     436     ind = torch.logical_and(d < l0 + l1 + l2, d>=l0 + l1)
#
# KeyboardInterrupt:
